# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (4.24.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from selenium) (2024.7.4)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\miniconda3\envs\mysql_python\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import sys
import urllib.request
import os

import time
import pandas as pd

# %%
wd = webdriver.Chrome()

# %%
# 해외 판매량

data_list = []

for i in range(2022,2025):
    # 2022 ~ 2024
    for j in range(1,13):
        # 2022-01 ~ 2024-07까지만 출력
        if i == 2024 and j == 8:
            break;
        
        wd.get(f'https://auto.danawa.com/auto/?Work=record&Tab=Grand&Month={i}-{j:02}-00')
        time.sleep(2)
        
        element = wd.find_element(By.CSS_SELECTOR, '#autodanawa_gridC > div.gridMain > article > main > div:nth-child(2) > table > tbody')
        rows = element.find_elements(By.TAG_NAME, 'tr')
        
        sales_month = f'{i}-{j:02}'
        print(sales_month)

        count = 0
        for row in rows:
            count +=1
            if count == 6:
                break
            # 다른 class 속성이 있는 경우 건너뜀 - <tr>에 대해서만 작동
            class_attribute = row.get_attribute('class')
            if class_attribute and ('sub' in class_attribute or 'model_' in class_attribute):
                continue  
            
            # 회사명
            company_element = row.find_element(By.CSS_SELECTOR, 'td.title a')
            company_name = company_element.text.strip()  # 회사명
            
            # 판매량
            sales = row.find_element(By.CLASS_NAME, 'num').text.split(' ')[0].replace(',', '')
            
            # 점유율
            market_share = row.find_element(By.CLASS_NAME, 'rate').text.replace('%', '')
            
            # 전월 대비 판매량 추출
            format_change = lambda text: '-' + text.split('▼')[0].strip() if '▼' in text else text.split('▲')[0].strip()
            last_month_values = row.find_elements(By.CLASS_NAME, 'right')[1].text.split('\n')
            
            last_month_sales = last_month_values[0].replace(',', '') # 전월 판매량
            last_month_change = format_change(last_month_values[1]).replace(',', '') # 전월 대비 증감
            
            data_dict = {
                '회사명': company_name,
                '판매량': sales,
                '점유율': market_share,
                '전월 판매량': last_month_sales,
                '전월 대비 증감': last_month_change,
                '판매월' : sales_month
            }
            print(data_dict)
            data_list.append(data_dict)
# Out:
# 2022-01
# {'회사명': 'BMW', '판매량': '5550', '점유율': '32.8', '전월 판매량': '4233', '전월 대비 증감': '1317', '판매월': '2022-01'}
# {'회사명': '벤츠', '판매량': '3405', '점유율': '20.1', '전월 판매량': '6752', '전월 대비 증감': '-3347', '판매월': '2022-01'}
# {'회사명': '아우디', '판매량': '1269', '점유율': '7.5', '전월 판매량': '4373', '전월 대비 증감': '-3104', '판매월': '2022-01'}
# {'회사명': '폭스바겐', '판매량': '1213', '점유율': '7.2', '전월 판매량': '920', '전월 대비 증감': '293', '판매월': '2022-01'}
# {'회사명': '볼보', '판매량': '1004', '점유율': '5.9', '전월 판매량': '1418', '전월 대비 증감': '-414', '판매월': '2022-01'}
# 2022-02
# {'회사명': '벤츠', '판매량': '5970', '점유율': '31.2', '전월 판매량': '3405', '전월 대비 증감': '2565', '판매월': '2022-02'}
# {'회사명': 'BMW', '판매량': '5656', '점유율': '29.6', '전월 판매량': '5550', '전월 대비 증감': '106', '판매월': '2022-02'}
# {'회사명': '아우디', '판매량': '1227', '점유율': '6.4', '전월 판매량': '1269', '전월 대비 증감': '-42', '판매월': '2022-02'}
# {'회사명': '폭스바겐', '판매량': '1108', '점유율': '5.8', '전월 판매량': '1213', '전월 대비 증감': '-105', '판매월': '2022-02'}
# {'회사명': '볼보', '판매량': '1047', '점유율': '5.5', '전월 판매량': '1004', '전월 대비 증감': '43', '판매월': '2022-02'}
# 2022-03
# {'회사명': '벤츠', '판매량': '8767', '점유율': '32.4', '전월 판매량': '5970', '전월 대비 증감': '2797', '판매월': '2022-03'}
# {'회사명': 'BMW', '판매량': '6837', '점유율': '25.3', '전월 판매량': '5656', '전월 대비 증감': '1181', '판매월': '2022-03'}
# {'회사명': '테슬라', '판매량': '2496', '점유율': '9.2', '전월 판매량': '205', '전월 대비 증감': '2291', '판매월': '2022-03'}
# {'회사명': '볼보', '판매량': '1309', '점유율': '4.8', '전월 판매량': '1047', '전월 대비 증감': '262', '판매월': '2022-03'}
# {'회사명': '미니', '판매량': '1273', '점유율': '4.7', '전월 판매량': '732', '전월 대비 증감': '541', '판매월': '2022-03'}
# 2022-04
# {'회사명': '벤츠', '판매량': '7822', '점유율': '34.3', '전월 판매량': '8767', '전월 대비 증감': '-945', '판매월': '2022-04'}
# {'회사명': 'BMW', '판매량': '6658', '점유율': '29.2', '전월 판매량': '6837', '전월 대비 증감': '-179', '판매월': '2022-04'}
# {'회사명': '볼보', '판매량': '1332', '점유율': '5.8', '전월 판매량': '1309', '전월 대비 증감': '23', '판매월': '2022-04'}
# {'회사명': '아우디', '판매량': '1051', '점유율': '4.6', '전월 판매량': '1155', '전월 대비 증감': '-104', '판매월': '2022-04'}
# {'회사명': '포르쉐', '판매량': '918', '점유율': '4.0', '전월 판매량': '951', '전월 대비 증감': '-33', '판매월': '2022-04'}
# 2022-05
# {'회사명': '벤츠', '판매량': '7388', '점유율': '29.6', '전월 판매량': '7822', '전월 대비 증감': '-434', '판매월': '2022-05'}
# {'회사명': 'BMW', '판매량': '6402', '점유율': '25.6', '전월 판매량': '6658', '전월 대비 증감': '-256', '판매월': '2022-05'}
# {'회사명': '테슬라', '판매량': '1880', '점유율': '7.5', '전월 판매량': '1', '전월 대비 증감': '1879', '판매월': '2022-05'}
# {'회사명': '아우디', '판매량': '1865', '점유율': '7.5', '전월 판매량': '1051', '전월 대비 증감': '814', '판매월': '2022-05'}
# {'회사명': '폭스바겐', '판매량': '1182', '점유율': '4.7', '전월 판매량': '847', '전월 대비 증감': '335', '판매월': '2022-05'}
# 2022-06
# {'회사명': 'BMW', '판매량': '6449', '점유율': '26.6', '전월 판매량': '6402', '전월 대비 증감': '47', '판매월': '2022-06'}
# {'회사명': '벤츠', '판매량': '5845', '점유율': '24.1', '전월 판매량': '7388', '전월 대비 증감': '-1543', '판매월': '2022-06'}
# {'회사명': '테슬라', '판매량': '2163', '점유율': '8.9', '전월 판매량': '1880', '전월 대비 증감': '283', '판매월': '2022-06'}
# {'회사명': '아우디', '판매량': '1903', '점유율': '7.9', '전월 판매량': '1865', '전월 대비 증감': '38', '판매월': '2022-06'}
# {'회사명': '볼보', '판매량': '1306', '점유율': '5.4', '전월 판매량': '1015', '전월 대비 증감': '291', '판매월': '2022-06'}
# 2022-07
# {'회사명': 'BMW', '판매량': '5490', '점유율': '26.9', '전월 판매량': '6449', '전월 대비 증감': '-959', '판매월': '2022-07'}
# {'회사명': '벤츠', '판매량': '5456', '점유율': '26.7', '전월 판매량': '5845', '전월 대비 증감': '-389', '판매월': '2022-07'}
# {'회사명': '아우디', '판매량': '1865', '점유율': '9.1', '전월 판매량': '1903', '전월 대비 증감': '-38', '판매월': '2022-07'}
# {'회사명': '폭스바겐', '판매량': '1041', '점유율': '5.1', '전월 판매량': '1099', '전월 대비 증감': '-58', '판매월': '2022-07'}
# {'회사명': '볼보', '판매량': '1018', '점유율': '5.0', '전월 판매량': '1306', '전월 대비 증감': '-288', '판매월': '2022-07'}
# 2022-08
# {'회사명': 'BMW', '판매량': '7303', '점유율': '28.2', '전월 판매량': '5490', '전월 대비 증감': '1813', '판매월': '2022-08'}
# {'회사명': '벤츠', '판매량': '5940', '점유율': '22.9', '전월 판매량': '5456', '전월 대비 증감': '484', '판매월': '2022-08'}
# {'회사명': '테슬라', '판매량': '3153', '점유율': '12.2', '전월 판매량': '0', '전월 대비 증감': '3153', '판매월': '2022-08'}
# {'회사명': '아우디', '판매량': '2310', '점유율': '8.9', '전월 판매량': '1865', '전월 대비 증감': '445', '판매월': '2022-08'}
# {'회사명': '폭스바겐', '판매량': '1043', '점유율': '4.0', '전월 판매량': '1041', '전월 대비 증감': '2', '판매월': '2022-08'}
# 2022-09
# {'회사명': 'BMW', '판매량': '7405', '점유율': '28.6', '전월 판매량': '7303', '전월 대비 증감': '102', '판매월': '2022-09'}
# {'회사명': '벤츠', '판매량': '5481', '점유율': '21.2', '전월 판매량': '5940', '전월 대비 증감': '-459', '판매월': '2022-09'}
# {'회사명': '테슬라', '판매량': '3133', '점유율': '12.1', '전월 판매량': '3153', '전월 대비 증감': '-20', '판매월': '2022-09'}
# {'회사명': '아우디', '판매량': '1812', '점유율': '7.0', '전월 판매량': '2310', '전월 대비 증감': '-498', '판매월': '2022-09'}
# {'회사명': '폭스바겐', '판매량': '1470', '점유율': '5.7', '전월 판매량': '1043', '전월 대비 증감': '427', '판매월': '2022-09'}
# 2022-10
# {'회사명': '벤츠', '판매량': '7717', '점유율': '32.4', '전월 판매량': '5481', '전월 대비 증감': '2236', '판매월': '2022-10'}
# {'회사명': 'BMW', '판매량': '6754', '점유율': '28.4', '전월 판매량': '7405', '전월 대비 증감': '-651', '판매월': '2022-10'}
# {'회사명': '아우디', '판매량': '2637', '점유율': '11.1', '전월 판매량': '1812', '전월 대비 증감': '825', '판매월': '2022-10'}
# {'회사명': '폭스바겐', '판매량': '1114', '점유율': '4.7', '전월 판매량': '1470', '전월 대비 증감': '-356', '판매월': '2022-10'}
# {'회사명': '렉서스', '판매량': '781', '점유율': '3.3', '전월 판매량': '860', '전월 대비 증감': '-79', '판매월': '2022-10'}
# 2022-11
# {'회사명': '벤츠', '판매량': '7734', '점유율': '27.1', '전월 판매량': '7717', '전월 대비 증감': '17', '판매월': '2022-11'}
# {'회사명': 'BMW', '판매량': '7209', '점유율': '25.3', '전월 판매량': '6754', '전월 대비 증감': '455', '판매월': '2022-11'}
# {'회사명': '볼보', '판매량': '2615', '점유율': '9.2', '전월 판매량': '566', '전월 대비 증감': '2049', '판매월': '2022-11'}
# {'회사명': '폭스바겐', '판매량': '1943', '점유율': '6.8', '전월 판매량': '1114', '전월 대비 증감': '829', '판매월': '2022-11'}
# {'회사명': '아우디', '판매량': '1667', '점유율': '5.8', '전월 판매량': '2637', '전월 대비 증감': '-970', '판매월': '2022-11'}
# 2022-12
# {'회사명': '벤츠', '판매량': '9451', '점유율': '32.2', '전월 판매량': '7734', '전월 대비 증감': '1717', '판매월': '2022-12'}
# {'회사명': 'BMW', '판매량': '6832', '점유율': '23.3', '전월 판매량': '7209', '전월 대비 증감': '-377', '판매월': '2022-12'}
# {'회사명': '폭스바겐', '판매량': '2678', '점유율': '9.1', '전월 판매량': '1943', '전월 대비 증감': '735', '판매월': '2022-12'}
# {'회사명': '아우디', '판매량': '2641', '점유율': '9.0', '전월 판매량': '1667', '전월 대비 증감': '974', '판매월': '2022-12'}
# {'회사명': '볼보', '판매량': '1813', '점유율': '6.2', '전월 판매량': '2615', '전월 대비 증감': '-802', '판매월': '2022-12'}
# 2023-01
# {'회사명': 'BMW', '판매량': '6089', '점유율': '38.4', '전월 판매량': '6832', '전월 대비 증감': '-743', '판매월': '2023-01'}
# {'회사명': '벤츠', '판매량': '2900', '점유율': '18.3', '전월 판매량': '9451', '전월 대비 증감': '-6551', '판매월': '2023-01'}
# {'회사명': '아우디', '판매량': '2454', '점유율': '15.5', '전월 판매량': '2641', '전월 대비 증감': '-187', '판매월': '2023-01'}
# {'회사명': '볼보', '판매량': '1007', '점유율': '6.3', '전월 판매량': '1813', '전월 대비 증감': '-806', '판매월': '2023-01'}
# {'회사명': '포르쉐', '판매량': '726', '점유율': '4.6', '전월 판매량': '985', '전월 대비 증감': '-259', '판매월': '2023-01'}
# 2023-02
# {'회사명': 'BMW', '판매량': '6381', '점유율': '29.8', '전월 판매량': '6089', '전월 대비 증감': '292', '판매월': '2023-02'}
# {'회사명': '벤츠', '판매량': '5519', '점유율': '25.8', '전월 판매량': '2900', '전월 대비 증감': '2619', '판매월': '2023-02'}
# {'회사명': '아우디', '판매량': '2200', '점유율': '10.3', '전월 판매량': '2454', '전월 대비 증감': '-254', '판매월': '2023-02'}
# {'회사명': '렉서스', '판매량': '1344', '점유율': '6.3', '전월 판매량': '576', '전월 대비 증감': '768', '판매월': '2023-02'}
# {'회사명': '포르쉐', '판매량': '1123', '점유율': '5.2', '전월 판매량': '726', '전월 대비 증감': '397', '판매월': '2023-02'}
# 2023-03
# {'회사명': '벤츠', '판매량': '6533', '점유율': '26.6', '전월 판매량': '5519', '전월 대비 증감': '1014', '판매월': '2023-03'}
# {'회사명': 'BMW', '판매량': '5664', '점유율': '23.1', '전월 판매량': '6381', '전월 대비 증감': '-717', '판매월': '2023-03'}
# {'회사명': '아우디', '판매량': '2260', '점유율': '9.2', '전월 판매량': '2200', '전월 대비 증감': '60', '판매월': '2023-03'}
# {'회사명': '볼보', '판매량': '2156', '점유율': '8.8', '전월 판매량': '827', '전월 대비 증감': '1329', '판매월': '2023-03'}
# {'회사명': '렉서스', '판매량': '1376', '점유율': '5.6', '전월 판매량': '1344', '전월 대비 증감': '32', '판매월': '2023-03'}
# 2023-04
# {'회사명': '벤츠', '판매량': '6176', '점유율': '30.4', '전월 판매량': '6533', '전월 대비 증감': '-357', '판매월': '2023-04'}
# {'회사명': 'BMW', '판매량': '5836', '점유율': '28.7', '전월 판매량': '5664', '전월 대비 증감': '172', '판매월': '2023-04'}
# {'회사명': '볼보', '판매량': '1599', '점유율': '7.9', '전월 판매량': '2156', '전월 대비 증감': '-557', '판매월': '2023-04'}
# {'회사명': '포르쉐', '판매량': '1146', '점유율': '5.6', '전월 판매량': '1117', '전월 대비 증감': '29', '판매월': '2023-04'}
# {'회사명': '렉서스', '판매량': '1025', '점유율': '5.0', '전월 판매량': '1376', '전월 대비 증감': '-351', '판매월': '2023-04'}
# 2023-05
# {'회사명': '벤츠', '판매량': '6292', '점유율': '29.4', '전월 판매량': '6176', '전월 대비 증감': '116', '판매월': '2023-05'}
# {'회사명': 'BMW', '판매량': '6036', '점유율': '28.2', '전월 판매량': '5836', '전월 대비 증감': '200', '판매월': '2023-05'}
# {'회사명': '볼보', '판매량': '1502', '점유율': '7.0', '전월 판매량': '1599', '전월 대비 증감': '-97', '판매월': '2023-05'}
# {'회사명': '포르쉐', '판매량': '1005', '점유율': '4.7', '전월 판매량': '1146', '전월 대비 증감': '-141', '판매월': '2023-05'}
# {'회사명': '렉서스', '판매량': '974', '점유율': '4.6', '전월 판매량': '1025', '전월 대비 증감': '-51', '판매월': '2023-05'}
# 2023-06
# {'회사명': 'BMW', '판매량': '8100', '점유율': '28.7', '전월 판매량': '6036', '전월 대비 증감': '2064', '판매월': '2023-06'}
# {'회사명': '벤츠', '판매량': '8003', '점유율': '28.4', '전월 판매량': '6292', '전월 대비 증감': '1711', '판매월': '2023-06'}
# {'회사명': '테슬라', '판매량': '1891', '점유율': '6.7', '전월 판매량': '424', '전월 대비 증감': '1467', '판매월': '2023-06'}
# {'회사명': '렉서스', '판매량': '1655', '점유율': '5.9', '전월 판매량': '974', '전월 대비 증감': '681', '판매월': '2023-06'}
# {'회사명': '볼보', '판매량': '1372', '점유율': '4.9', '전월 판매량': '1502', '전월 대비 증감': '-130', '판매월': '2023-06'}
# 2023-07
# {'회사명': 'BMW', '판매량': '5931', '점유율': '28.6', '전월 판매량': '8100', '전월 대비 증감': '-2169', '판매월': '2023-07'}
# {'회사명': '벤츠', '판매량': '5394', '점유율': '26.0', '전월 판매량': '8003', '전월 대비 증감': '-2609', '판매월': '2023-07'}
# {'회사명': '아우디', '판매량': '1504', '점유율': '7.3', '전월 판매량': '1347', '전월 대비 증감': '157', '판매월': '2023-07'}
# {'회사명': '볼보', '판매량': '1409', '점유율': '6.8', '전월 판매량': '1372', '전월 대비 증감': '37', '판매월': '2023-07'}
# {'회사명': '폭스바겐', '판매량': '1195', '점유율': '5.8', '전월 판매량': '538', '전월 대비 증감': '657', '판매월': '2023-07'}
# 2023-08
# {'회사명': '벤츠', '판매량': '6588', '점유율': '28.0', '전월 판매량': '5394', '전월 대비 증감': '1194', '판매월': '2023-08'}
# {'회사명': 'BMW', '판매량': '6304', '점유율': '26.8', '전월 판매량': '5931', '전월 대비 증감': '373', '판매월': '2023-08'}
# {'회사명': '아우디', '판매량': '1551', '점유율': '6.6', '전월 판매량': '1504', '전월 대비 증감': '47', '판매월': '2023-08'}
# {'회사명': '폭스바겐', '판매량': '1417', '점유율': '6.0', '전월 판매량': '1195', '전월 대비 증감': '222', '판매월': '2023-08'}
# {'회사명': '포르쉐', '판매량': '1111', '점유율': '4.7', '전월 판매량': '953', '전월 대비 증감': '158', '판매월': '2023-08'}
# 2023-09
# {'회사명': '벤츠', '판매량': '6971', '점유율': '26.3', '전월 판매량': '6588', '전월 대비 증감': '383', '판매월': '2023-09'}
# {'회사명': 'BMW', '판매량': '6188', '점유율': '23.3', '전월 판매량': '6304', '전월 대비 증감': '-116', '판매월': '2023-09'}
# {'회사명': '테슬라', '판매량': '4501', '점유율': '17.0', '전월 판매량': '696', '전월 대비 증감': '3805', '판매월': '2023-09'}
# {'회사명': '볼보', '판매량': '1555', '점유율': '5.9', '전월 판매량': '1080', '전월 대비 증감': '475', '판매월': '2023-09'}
# {'회사명': '아우디', '판매량': '1416', '점유율': '5.3', '전월 판매량': '1551', '전월 대비 증감': '-135', '판매월': '2023-09'}
# 2023-10
# {'회사명': '벤츠', '판매량': '6612', '점유율': '28.1', '전월 판매량': '6971', '전월 대비 증감': '-359', '판매월': '2023-10'}
# {'회사명': 'BMW', '판매량': '5985', '점유율': '25.4', '전월 판매량': '6188', '전월 대비 증감': '-203', '판매월': '2023-10'}
# {'회사명': '테슬라', '판매량': '2829', '점유율': '12.0', '전월 판매량': '4501', '전월 대비 증감': '-1672', '판매월': '2023-10'}
# {'회사명': '볼보', '판매량': '1263', '점유율': '5.4', '전월 판매량': '1555', '전월 대비 증감': '-292', '판매월': '2023-10'}
# {'회사명': '아우디', '판매량': '1151', '점유율': '4.9', '전월 판매량': '1416', '전월 대비 증감': '-265', '판매월': '2023-10'}
# 2023-11
# {'회사명': '벤츠', '판매량': '7168', '점유율': '25.9', '전월 판매량': '6612', '전월 대비 증감': '556', '판매월': '2023-11'}
# {'회사명': 'BMW', '판매량': '7032', '점유율': '25.4', '전월 판매량': '5985', '전월 대비 증감': '1047', '판매월': '2023-11'}
# {'회사명': '테슬라', '판매량': '3562', '점유율': '12.8', '전월 판매량': '2829', '전월 대비 증감': '733', '판매월': '2023-11'}
# {'회사명': '볼보', '판매량': '1640', '점유율': '5.9', '전월 판매량': '1263', '전월 대비 증감': '377', '판매월': '2023-11'}
# {'회사명': '아우디', '판매량': '1392', '점유율': '5.0', '전월 판매량': '1151', '전월 대비 증감': '241', '판매월': '2023-11'}
# 2023-12
# {'회사명': '벤츠', '판매량': '8541', '점유율': '30.4', '전월 판매량': '7168', '전월 대비 증감': '1373', '판매월': '2023-12'}
# {'회사명': 'BMW', '판매량': '7849', '점유율': '27.9', '전월 판매량': '7032', '전월 대비 증감': '817', '판매월': '2023-12'}
# {'회사명': '볼보', '판매량': '1608', '점유율': '5.7', '전월 판매량': '1640', '전월 대비 증감': '-32', '판매월': '2023-12'}
# {'회사명': '폭스바겐', '판매량': '1462', '점유율': '5.2', '전월 판매량': '966', '전월 대비 증감': '496', '판매월': '2023-12'}
# {'회사명': '렉서스', '판매량': '1370', '점유율': '4.9', '전월 판매량': '1183', '전월 대비 증감': '187', '판매월': '2023-12'}
# 2024-01
# {'회사명': 'BMW', '판매량': '4330', '점유율': '33.5', '전월 판매량': '7849', '전월 대비 증감': '-3519', '판매월': '2024-01'}
# {'회사명': '벤츠', '판매량': '2931', '점유율': '22.7', '전월 판매량': '8541', '전월 대비 증감': '-5610', '판매월': '2024-01'}
# {'회사명': '렉서스', '판매량': '998', '점유율': '7.7', '전월 판매량': '1370', '전월 대비 증감': '-372', '판매월': '2024-01'}
# {'회사명': '볼보', '판매량': '965', '점유율': '7.5', '전월 판매량': '1608', '전월 대비 증감': '-643', '판매월': '2024-01'}
# {'회사명': '토요타', '판매량': '786', '점유율': '6.1', '전월 판매량': '893', '전월 대비 증감': '-107', '판매월': '2024-01'}
# 2024-02
# {'회사명': 'BMW', '판매량': '6089', '점유율': '37.8', '전월 판매량': '4330', '전월 대비 증감': '1759', '판매월': '2024-02'}
# {'회사명': '벤츠', '판매량': '3592', '점유율': '22.3', '전월 판매량': '2931', '전월 대비 증감': '661', '판매월': '2024-02'}
# {'회사명': '볼보', '판매량': '961', '점유율': '6.0', '전월 판매량': '965', '전월 대비 증감': '-4', '판매월': '2024-02'}
# {'회사명': '렉서스', '판매량': '919', '점유율': '5.7', '전월 판매량': '998', '전월 대비 증감': '-79', '판매월': '2024-02'}
# {'회사명': '포르쉐', '판매량': '828', '점유율': '5.1', '전월 판매량': '677', '전월 대비 증감': '151', '판매월': '2024-02'}
# 2024-03
# {'회사명': 'BMW', '판매량': '6549', '점유율': '26.0', '전월 판매량': '6089', '전월 대비 증감': '460', '판매월': '2024-03'}
# {'회사명': '테슬라', '판매량': '6025', '점유율': '24.0', '전월 판매량': '174', '전월 대비 증감': '5851', '판매월': '2024-03'}
# {'회사명': '벤츠', '판매량': '4197', '점유율': '16.7', '전월 판매량': '3592', '전월 대비 증감': '605', '판매월': '2024-03'}
# {'회사명': '렉서스', '판매량': '1218', '점유율': '4.8', '전월 판매량': '919', '전월 대비 증감': '299', '판매월': '2024-03'}
# {'회사명': '볼보', '판매량': '1081', '점유율': '4.3', '전월 판매량': '961', '전월 대비 증감': '120', '판매월': '2024-03'}
# 2024-04
# {'회사명': '벤츠', '판매량': '6683', '점유율': '31.1', '전월 판매량': '4197', '전월 대비 증감': '2486', '판매월': '2024-04'}
# {'회사명': 'BMW', '판매량': '5750', '점유율': '26.8', '전월 판매량': '6549', '전월 대비 증감': '-799', '판매월': '2024-04'}
# {'회사명': '테슬라', '판매량': '1722', '점유율': '8.0', '전월 판매량': '6025', '전월 대비 증감': '-4303', '판매월': '2024-04'}
# {'회사명': '볼보', '판매량': '1210', '점유율': '5.6', '전월 판매량': '1081', '전월 대비 증감': '129', '판매월': '2024-04'}
# {'회사명': '렉서스', '판매량': '920', '점유율': '4.3', '전월 판매량': '1218', '전월 대비 증감': '-298', '판매월': '2024-04'}
# 2024-05
# {'회사명': 'BMW', '판매량': '6240', '점유율': '25.9', '전월 판매량': '5750', '전월 대비 증감': '490', '판매월': '2024-05'}
# {'회사명': '벤츠', '판매량': '5947', '점유율': '24.6', '전월 판매량': '6683', '전월 대비 증감': '-736', '판매월': '2024-05'}
# {'회사명': '테슬라', '판매량': '4165', '점유율': '17.3', '전월 판매량': '1722', '전월 대비 증감': '2443', '판매월': '2024-05'}
# {'회사명': '볼보', '판매량': '1516', '점유율': '6.3', '전월 판매량': '1210', '전월 대비 증감': '306', '판매월': '2024-05'}
# {'회사명': '렉서스', '판매량': '1319', '점유율': '5.5', '전월 판매량': '920', '전월 대비 증감': '399', '판매월': '2024-05'}
# 2024-06
# {'회사명': '벤츠', '판매량': '6661', '점유율': '26.4', '전월 판매량': '5947', '전월 대비 증감': '714', '판매월': '2024-06'}
# {'회사명': 'BMW', '판매량': '6172', '점유율': '24.5', '전월 판매량': '6240', '전월 대비 증감': '-68', '판매월': '2024-06'}
# {'회사명': '테슬라', '판매량': '5293', '점유율': '21.0', '전월 판매량': '4165', '전월 대비 증감': '1128', '판매월': '2024-06'}
# {'회사명': '볼보', '판매량': '1452', '점유율': '5.8', '전월 판매량': '1516', '전월 대비 증감': '-64', '판매월': '2024-06'}
# {'회사명': '렉서스', '판매량': '1047', '점유율': '4.2', '전월 판매량': '1319', '전월 대비 증감': '-272', '판매월': '2024-06'}
# 2024-07
# {'회사명': 'BMW', '판매량': '6380', '점유율': '29.2', '전월 판매량': '6172', '전월 대비 증감': '208', '판매월': '2024-07'}
# {'회사명': '벤츠', '판매량': '4369', '점유율': '20.0', '전월 판매량': '6661', '전월 대비 증감': '-2292', '판매월': '2024-07'}
# {'회사명': '테슬라', '판매량': '2680', '점유율': '12.3', '전월 판매량': '5293', '전월 대비 증감': '-2613', '판매월': '2024-07'}
# {'회사명': '볼보', '판매량': '1411', '점유율': '6.5', '전월 판매량': '1452', '전월 대비 증감': '-41', '판매월': '2024-07'}
# {'회사명': '렉서스', '판매량': '1108', '점유율': '5.1', '전월 판매량': '1047', '전월 대비 증감': '61', '판매월': '2024-07'}

# %%
df = pd.DataFrame(data_list)
df
# Out:
#       회사명   판매량   점유율 전월 판매량 전월 대비 증감      판매월
# 0     BMW  5550  32.8   4233     1317  2022-01
# 1      벤츠  3405  20.1   6752    -3347  2022-01
# 2     아우디  1269   7.5   4373    -3104  2022-01
# 3    폭스바겐  1213   7.2    920      293  2022-01
# 4      볼보  1004   5.9   1418     -414  2022-01
# ..    ...   ...   ...    ...      ...      ...
# 150   BMW  6380  29.2   6172      208  2024-07
# 151    벤츠  4369  20.0   6661    -2292  2024-07
# 152   테슬라  2680  12.3   5293    -2613  2024-07
# 153    볼보  1411   6.5   1452      -41  2024-07
# 154   렉서스  1108   5.1   1047       61  2024-07
#
# [155 rows x 6 columns]

# %%
import mysql.connector

# 데이터베이스 연결 설정
db_config = {
    'host': 'localhost',
    'user': 'root',
    'password': '1234',
    'database': 'pjt01'
}


# 데이터베이스 연결
try:
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor(buffered=True)

    for entry in data_list:
        company_name = entry['회사명']
        
        # 모델명을 통해 vehicle_id 가져오기
        cursor.execute("SELECT company_id FROM company WHERE company_name = %s", (company_name,))
        company_id = cursor.fetchone()
        
        if company_id:
            company_id = company_id[0]  # 첫 번째 요소 가져오기
            
            # 데이터 삽입
            cursor.execute("""
                INSERT INTO international_company_sales (sales, market_share, last_month_sales, last_month_change, sales_month, company_id) 
                VALUES (%s, %s, %s, %s, %s, %s)
            """, (entry['판매량'], entry['점유율'], entry['전월 판매량'], entry['전월 대비 증감'], entry['판매월']+'-01', company_id))
        else:
            print(f"{company_name}에 대한 company_id를 찾을 수 없습니다.")

    # 변경 사항 커밋
    conn.commit()
    print("데이터가 성공적으로 삽입되었습니다.")

except mysql.connector.Error as err:
    print(f"오류 발생: {err}")

finally:
    if cursor:
        cursor.close()
    if conn:
        conn.close()
# Out:
# 데이터가 성공적으로 삽입되었습니다.

# %%
# 국내 판매량

data_list = []

for i in range(2022,2025):
    # 2022 ~ 2024
    for j in range(1,13):
        # 2022-01 ~ 2024-08까지만 출력
        if i == 2024 and j == 9:
            break;
        
        wd.get(f'https://auto.danawa.com/auto/?Work=record&Tab=Grand&Month={i}-{j:02}-00')
        time.sleep(2)
        
        element = wd.find_element(By.CSS_SELECTOR, '#autodanawa_gridC > div.gridMain > article > main > div:nth-child(1) > table > tbody')
        rows = element.find_elements(By.TAG_NAME, 'tr')
        
        sales_month = f'{i}-{j:02}'
        print(sales_month)

        for row in rows:
            # 다른 class 속성이 있는 경우 건너뜀 - <tr>에 대해서만 작동
            class_attribute = row.get_attribute('class')
            if class_attribute and ('sub' in class_attribute or 'model_' in class_attribute):
                continue  
            
            # 회사명
            company_element = row.find_element(By.CSS_SELECTOR, 'td.title a')
            company_name = company_element.text.strip()  # 회사명
            
            # 판매량
            sales = row.find_element(By.CLASS_NAME, 'num').text.split(' ')[0].replace(',', '')
            
            # 점유율
            market_share = row.find_element(By.CLASS_NAME, 'rate').text.replace('%', '')
            
            # 전월 대비 판매량 추출
            format_change = lambda text: '-' + text.split('▼')[0].strip() if '▼' in text else text.split('▲')[0].strip()
            last_month_values = row.find_elements(By.CLASS_NAME, 'right')[1].text.split('\n')
            
            last_month_sales = last_month_values[0].replace(',', '') # 전월 판매량
            last_month_change = format_change(last_month_values[1]).replace(',', '') # 전월 대비 증감
            
            data_dict = {
                '회사명': company_name,
                '판매량': sales,
                '점유율': market_share,
                '전월 판매량': last_month_sales,
                '전월 대비 증감': last_month_change,
                '판매월' : sales_month
            }
            print(data_dict)
            data_list.append(data_dict)
# Out:
# 2022-01
# {'회사명': '기아', '판매량': '37038', '점유율': '39.4', '전월 판매량': '47789', '전월 대비 증감': '-10751', '판매월': '2022-01'}
# {'회사명': '현대', '판매량': '35625', '점유율': '37.9', '전월 판매량': '51240', '전월 대비 증감': '-15615', '판매월': '2022-01'}
# {'회사명': '제네시스', '판매량': '10575', '점유율': '11.3', '전월 판매량': '14872', '전월 대비 증감': '-4297', '판매월': '2022-01'}
# {'회사명': 'KGM', '판매량': '4836', '점유율': '5.2', '전월 판매량': '5810', '전월 대비 증감': '-974', '판매월': '2022-01'}
# {'회사명': '르노코리아', '판매량': '4477', '점유율': '4.8', '전월 판매량': '7162', '전월 대비 증감': '-2685', '판매월': '2022-01'}
# {'회사명': '쉐보레', '판매량': '1344', '점유율': '1.4', '전월 판매량': '2519', '전월 대비 증감': '-1175', '판매월': '2022-01'}
# 2022-02
# {'회사명': '현대', '판매량': '41994', '점유율': '40.7', '전월 판매량': '35625', '전월 대비 증감': '6369', '판매월': '2022-02'}
# {'회사명': '기아', '판매량': '39560', '점유율': '38.3', '전월 판매량': '37038', '전월 대비 증감': '2522', '판매월': '2022-02'}
# {'회사명': '제네시스', '판매량': '11016', '점유율': '10.7', '전월 판매량': '10575', '전월 대비 증감': '441', '판매월': '2022-02'}
# {'회사명': 'KGM', '판매량': '4540', '점유율': '4.4', '전월 판매량': '4836', '전월 대비 증감': '-296', '판매월': '2022-02'}
# {'회사명': '르노코리아', '판매량': '3718', '점유율': '3.6', '전월 판매량': '4477', '전월 대비 증감': '-759', '판매월': '2022-02'}
# {'회사명': '쉐보레', '판매량': '2447', '점유율': '2.4', '전월 판매량': '1344', '전월 대비 증감': '1103', '판매월': '2022-02'}
# 2022-03
# {'회사명': '기아', '판매량': '45066', '점유율': '40.6', '전월 판매량': '39560', '전월 대비 증감': '5506', '판매월': '2022-03'}
# {'회사명': '현대', '판매량': '42052', '점유율': '37.8', '전월 판매량': '41994', '전월 대비 증감': '58', '판매월': '2022-03'}
# {'회사명': '제네시스', '판매량': '10831', '점유율': '9.7', '전월 판매량': '11016', '전월 대비 증감': '-185', '판매월': '2022-03'}
# {'회사명': 'KGM', '판매량': '5102', '점유율': '4.6', '전월 판매량': '4540', '전월 대비 증감': '562', '판매월': '2022-03'}
# {'회사명': '르노코리아', '판매량': '4464', '점유율': '4.0', '전월 판매량': '3718', '전월 대비 증감': '746', '판매월': '2022-03'}
# {'회사명': '쉐보레', '판매량': '3610', '점유율': '3.2', '전월 판매량': '2447', '전월 대비 증감': '1163', '판매월': '2022-03'}
# 2022-04
# {'회사명': '기아', '판매량': '50095', '점유율': '41.9', '전월 판매량': '45066', '전월 대비 증감': '5029', '판매월': '2022-04'}
# {'회사명': '현대', '판매량': '48125', '점유율': '40.2', '전월 판매량': '42052', '전월 대비 증감': '6073', '판매월': '2022-04'}
# {'회사명': '제네시스', '판매량': '11290', '점유율': '9.4', '전월 판매량': '10831', '전월 대비 증감': '459', '판매월': '2022-04'}
# {'회사명': 'KGM', '판매량': '4839', '점유율': '4.0', '전월 판매량': '5102', '전월 대비 증감': '-263', '판매월': '2022-04'}
# {'회사명': '쉐보레', '판매량': '2951', '점유율': '2.5', '전월 판매량': '3610', '전월 대비 증감': '-659', '판매월': '2022-04'}
# {'회사명': '르노코리아', '판매량': '2328', '점유율': '1.9', '전월 판매량': '4464', '전월 대비 증감': '-2136', '판매월': '2022-04'}
# 2022-05
# {'회사명': '현대', '판매량': '51139', '점유율': '42.7', '전월 판매량': '48125', '전월 대비 증감': '3014', '판매월': '2022-05'}
# {'회사명': '기아', '판매량': '45663', '점유율': '38.1', '전월 판매량': '50095', '전월 대비 증감': '-4432', '판매월': '2022-05'}
# {'회사명': '제네시스', '판매량': '12234', '점유율': '10.2', '전월 판매량': '11290', '전월 대비 증감': '944', '판매월': '2022-05'}
# {'회사명': 'KGM', '판매량': '4275', '점유율': '3.6', '전월 판매량': '4839', '전월 대비 증감': '-564', '판매월': '2022-05'}
# {'회사명': '르노코리아', '판매량': '3728', '점유율': '3.1', '전월 판매량': '2328', '전월 대비 증감': '1400', '판매월': '2022-05'}
# {'회사명': '쉐보레', '판매량': '2768', '점유율': '2.3', '전월 판매량': '2951', '전월 대비 증감': '-183', '판매월': '2022-05'}
# 2022-06
# {'회사명': '현대', '판매량': '48298', '점유율': '39.9', '전월 판매량': '51139', '전월 대비 증감': '-2841', '판매월': '2022-06'}
# {'회사명': '기아', '판매량': '45110', '점유율': '37.2', '전월 판매량': '45663', '전월 대비 증감': '-553', '판매월': '2022-06'}
# {'회사명': '제네시스', '판매량': '11212', '점유율': '9.3', '전월 판매량': '12234', '전월 대비 증감': '-1022', '판매월': '2022-06'}
# {'회사명': '르노코리아', '판매량': '7515', '점유율': '6.2', '전월 판매량': '3728', '전월 대비 증감': '3787', '판매월': '2022-06'}
# {'회사명': 'KGM', '판매량': '4585', '점유율': '3.8', '전월 판매량': '4275', '전월 대비 증감': '310', '판매월': '2022-06'}
# {'회사명': '쉐보레', '판매량': '4433', '점유율': '3.7', '전월 판매량': '2768', '전월 대비 증감': '1665', '판매월': '2022-06'}
# 2022-07
# {'회사명': '기아', '판매량': '51355', '점유율': '42.0', '전월 판매량': '45110', '전월 대비 증감': '6245', '판매월': '2022-07'}
# {'회사명': '현대', '판매량': '45793', '점유율': '37.5', '전월 판매량': '48298', '전월 대비 증감': '-2505', '판매월': '2022-07'}
# {'회사명': '제네시스', '판매량': '10512', '점유율': '8.6', '전월 판매량': '11212', '전월 대비 증감': '-700', '판매월': '2022-07'}
# {'회사명': 'KGM', '판매량': '6100', '점유율': '5.0', '전월 판매량': '4585', '전월 대비 증감': '1515', '판매월': '2022-07'}
# {'회사명': '르노코리아', '판매량': '4257', '점유율': '3.5', '전월 판매량': '7515', '전월 대비 증감': '-3258', '판매월': '2022-07'}
# {'회사명': '쉐보레', '판매량': '4117', '점유율': '3.4', '전월 판매량': '4433', '전월 대비 증감': '-316', '판매월': '2022-07'}
# 2022-08
# {'회사명': '기아', '판매량': '41404', '점유율': '39.4', '전월 판매량': '51355', '전월 대비 증감': '-9951', '판매월': '2022-08'}
# {'회사명': '현대', '판매량': '39607', '점유율': '37.7', '전월 판매량': '45793', '전월 대비 증감': '-6186', '판매월': '2022-08'}
# {'회사명': '제네시스', '판매량': '9617', '점유율': '9.2', '전월 판매량': '10512', '전월 대비 증감': '-895', '판매월': '2022-08'}
# {'회사명': 'KGM', '판매량': '6923', '점유율': '6.6', '전월 판매량': '6100', '전월 대비 증감': '823', '판매월': '2022-08'}
# {'회사명': '르노코리아', '판매량': '3950', '점유율': '3.8', '전월 판매량': '4257', '전월 대비 증감': '-307', '판매월': '2022-08'}
# {'회사명': '쉐보레', '판매량': '3590', '점유율': '3.4', '전월 판매량': '4117', '전월 대비 증감': '-527', '판매월': '2022-08'}
# 2022-09
# {'회사명': '현대', '판매량': '47263', '점유율': '41.6', '전월 판매량': '39607', '전월 대비 증감': '7656', '판매월': '2022-09'}
# {'회사명': '기아', '판매량': '40009', '점유율': '35.2', '전월 판매량': '41404', '전월 대비 증감': '-1395', '판매월': '2022-09'}
# {'회사명': '제네시스', '판매량': '9646', '점유율': '8.5', '전월 판매량': '9617', '전월 대비 증감': '29', '판매월': '2022-09'}
# {'회사명': 'KGM', '판매량': '7675', '점유율': '6.8', '전월 판매량': '6923', '전월 대비 증감': '752', '판매월': '2022-09'}
# {'회사명': '르노코리아', '판매량': '5050', '점유율': '4.4', '전월 판매량': '3950', '전월 대비 증감': '1100', '판매월': '2022-09'}
# {'회사명': '쉐보레', '판매량': '4012', '점유율': '3.5', '전월 판매량': '3590', '전월 대비 증감': '422', '판매월': '2022-09'}
# 2022-10
# {'회사명': '현대', '판매량': '49444', '점유율': '41.2', '전월 판매량': '47263', '전월 대비 증감': '2181', '판매월': '2022-10'}
# {'회사명': '기아', '판매량': '43032', '점유율': '35.9', '전월 판매량': '40009', '전월 대비 증감': '3023', '판매월': '2022-10'}
# {'회사명': '제네시스', '판매량': '11291', '점유율': '9.4', '전월 판매량': '9646', '전월 대비 증감': '1645', '판매월': '2022-10'}
# {'회사명': 'KGM', '판매량': '7850', '점유율': '6.5', '전월 판매량': '7675', '전월 대비 증감': '175', '판매월': '2022-10'}
# {'회사명': '르노코리아', '판매량': '4338', '점유율': '3.6', '전월 판매량': '5050', '전월 대비 증감': '-712', '판매월': '2022-10'}
# {'회사명': '쉐보레', '판매량': '4070', '점유율': '3.4', '전월 판매량': '4012', '전월 대비 증감': '58', '판매월': '2022-10'}
# 2022-11
# {'회사명': '기아', '판매량': '52200', '점유율': '41.0', '전월 판매량': '43032', '전월 대비 증감': '9168', '판매월': '2022-11'}
# {'회사명': '현대', '판매량': '49356', '점유율': '38.8', '전월 판매량': '49444', '전월 대비 증감': '-88', '판매월': '2022-11'}
# {'회사명': '제네시스', '판매량': '11615', '점유율': '9.1', '전월 판매량': '11291', '전월 대비 증감': '324', '판매월': '2022-11'}
# {'회사명': 'KGM', '판매량': '6421', '점유율': '5.0', '전월 판매량': '7850', '전월 대비 증감': '-1429', '판매월': '2022-11'}
# {'회사명': '르노코리아', '판매량': '5553', '점유율': '4.4', '전월 판매량': '4338', '전월 대비 증감': '1215', '판매월': '2022-11'}
# {'회사명': '쉐보레', '판매량': '2057', '점유율': '1.6', '전월 판매량': '4070', '전월 대비 증감': '-2013', '판매월': '2022-11'}
# 2022-12
# {'회사명': '현대', '판매량': '54996', '점유율': '41.9', '전월 판매량': '49356', '전월 대비 증감': '5640', '판매월': '2022-12'}
# {'회사명': '기아', '판매량': '50536', '점유율': '38.5', '전월 판매량': '52200', '전월 대비 증감': '-1664', '판매월': '2022-12'}
# {'회사명': '제네시스', '판매량': '15205', '점유율': '11.6', '전월 판매량': '11615', '전월 대비 증감': '3590', '판매월': '2022-12'}
# {'회사명': 'KGM', '판매량': '5520', '점유율': '4.2', '전월 판매량': '6421', '전월 대비 증감': '-901', '판매월': '2022-12'}
# {'회사명': '르노코리아', '판매량': '3243', '점유율': '2.5', '전월 판매량': '5553', '전월 대비 증감': '-2310', '판매월': '2022-12'}
# {'회사명': '쉐보레', '판매량': '1840', '점유율': '1.4', '전월 판매량': '2057', '전월 대비 증감': '-217', '판매월': '2022-12'}
# 2023-01
# {'회사명': '현대', '판매량': '43527', '점유율': '43.1', '전월 판매량': '54996', '전월 대비 증감': '-11469', '판매월': '2023-01'}
# {'회사명': '기아', '판매량': '38753', '점유율': '38.4', '전월 판매량': '50536', '전월 대비 증감': '-11783', '판매월': '2023-01'}
# {'회사명': '제네시스', '판매량': '8355', '점유율': '8.3', '전월 판매량': '15205', '전월 대비 증감': '-6850', '판매월': '2023-01'}
# {'회사명': 'KGM', '판매량': '7130', '점유율': '7.1', '전월 판매량': '5520', '전월 대비 증감': '1610', '판매월': '2023-01'}
# {'회사명': '르노코리아', '판매량': '2116', '점유율': '2.1', '전월 판매량': '3243', '전월 대비 증감': '-1127', '판매월': '2023-01'}
# {'회사명': '쉐보레', '판매량': '1021', '점유율': '1.0', '전월 판매량': '1840', '전월 대비 증감': '-819', '판매월': '2023-01'}
# 2023-02
# {'회사명': '현대', '판매량': '55319', '점유율': '44.2', '전월 판매량': '43527', '전월 대비 증감': '11792', '판매월': '2023-02'}
# {'회사명': '기아', '판매량': '50105', '점유율': '40.0', '전월 판매량': '38753', '전월 대비 증감': '11352', '판매월': '2023-02'}
# {'회사명': '제네시스', '판매량': '9696', '점유율': '7.7', '전월 판매량': '8355', '전월 대비 증감': '1341', '판매월': '2023-02'}
# {'회사명': 'KGM', '판매량': '6785', '점유율': '5.4', '전월 판매량': '7130', '전월 대비 증감': '-345', '판매월': '2023-02'}
# {'회사명': '르노코리아', '판매량': '2218', '점유율': '1.8', '전월 판매량': '2116', '전월 대비 증감': '102', '판매월': '2023-02'}
# {'회사명': '쉐보레', '판매량': '1054', '점유율': '0.8', '전월 판매량': '1021', '전월 대비 증감': '33', '판매월': '2023-02'}
# 2023-03
# {'회사명': '현대', '판매량': '61794', '점유율': '43.9', '전월 판매량': '55319', '전월 대비 증감': '6475', '판매월': '2023-03'}
# {'회사명': '기아', '판매량': '53158', '점유율': '37.7', '전월 판매량': '50105', '전월 대비 증감': '3053', '판매월': '2023-03'}
# {'회사명': '제네시스', '판매량': '12735', '점유율': '9.0', '전월 판매량': '9696', '전월 대비 증감': '3039', '판매월': '2023-03'}
# {'회사명': 'KGM', '판매량': '8904', '점유율': '6.3', '전월 판매량': '6785', '전월 대비 증감': '2119', '판매월': '2023-03'}
# {'회사명': '르노코리아', '판매량': '2636', '점유율': '1.9', '전월 판매량': '2218', '전월 대비 증감': '418', '판매월': '2023-03'}
# {'회사명': '쉐보레', '판매량': '1636', '점유율': '1.2', '전월 판매량': '1054', '전월 대비 증감': '582', '판매월': '2023-03'}
# 2023-04
# {'회사명': '현대', '판매량': '54473', '점유율': '42.4', '전월 판매량': '61794', '전월 대비 증감': '-7321', '판매월': '2023-04'}
# {'회사명': '기아', '판매량': '49314', '점유율': '38.4', '전월 판매량': '53158', '전월 대비 증감': '-3844', '판매월': '2023-04'}
# {'회사명': '제네시스', '판매량': '12187', '점유율': '9.5', '전월 판매량': '12735', '전월 대비 증감': '-548', '판매월': '2023-04'}
# {'회사명': 'KGM', '판매량': '5583', '점유율': '4.3', '전월 판매량': '8904', '전월 대비 증감': '-3321', '판매월': '2023-04'}
# {'회사명': '쉐보레', '판매량': '5180', '점유율': '4.0', '전월 판매량': '1636', '전월 대비 증감': '3544', '판매월': '2023-04'}
# {'회사명': '르노코리아', '판매량': '1801', '점유율': '1.4', '전월 판매량': '2636', '전월 대비 증감': '-835', '판매월': '2023-04'}
# 2023-05
# {'회사명': '현대', '판매량': '56252', '점유율': '43.2', '전월 판매량': '54473', '전월 대비 증감': '1779', '판매월': '2023-05'}
# {'회사명': '기아', '판매량': '50364', '점유율': '38.6', '전월 판매량': '49314', '전월 대비 증감': '1050', '판매월': '2023-05'}
# {'회사명': '제네시스', '판매량': '12428', '점유율': '9.5', '전월 판매량': '12187', '전월 대비 증감': '241', '판매월': '2023-05'}
# {'회사명': 'KGM', '판매량': '4809', '점유율': '3.7', '전월 판매량': '5583', '전월 대비 증감': '-774', '판매월': '2023-05'}
# {'회사명': '쉐보레', '판매량': '4708', '점유율': '3.6', '전월 판매량': '5180', '전월 대비 증감': '-472', '판매월': '2023-05'}
# {'회사명': '르노코리아', '판매량': '1778', '점유율': '1.4', '전월 판매량': '1801', '전월 대비 증감': '-23', '판매월': '2023-05'}
# 2023-06
# {'회사명': '현대', '판매량': '56325', '점유율': '42.1', '전월 판매량': '56252', '전월 대비 증감': '73', '판매월': '2023-06'}
# {'회사명': '기아', '판매량': '51138', '점유율': '38.2', '전월 판매량': '50364', '전월 대비 증감': '774', '판매월': '2023-06'}
# {'회사명': '제네시스', '판매량': '13838', '점유율': '10.3', '전월 판매량': '12428', '전월 대비 증감': '1410', '판매월': '2023-06'}
# {'회사명': 'KGM', '판매량': '5758', '점유율': '4.3', '전월 판매량': '4809', '전월 대비 증감': '949', '판매월': '2023-06'}
# {'회사명': '쉐보레', '판매량': '5141', '점유율': '3.8', '전월 판매량': '4708', '전월 대비 증감': '433', '판매월': '2023-06'}
# {'회사명': '르노코리아', '판매량': '1721', '점유율': '1.3', '전월 판매량': '1778', '전월 대비 증감': '-57', '판매월': '2023-06'}
# 2023-07
# {'회사명': '기아', '판매량': '47507', '점유율': '41.4', '전월 판매량': '51138', '전월 대비 증감': '-3631', '판매월': '2023-07'}
# {'회사명': '현대', '판매량': '47048', '점유율': '41.0', '전월 판매량': '56325', '전월 대비 증감': '-9277', '판매월': '2023-07'}
# {'회사명': '제네시스', '판매량': '10455', '점유율': '9.1', '전월 판매량': '13838', '전월 대비 증감': '-3383', '판매월': '2023-07'}
# {'회사명': '쉐보레', '판매량': '4086', '점유율': '3.6', '전월 판매량': '5141', '전월 대비 증감': '-1055', '판매월': '2023-07'}
# {'회사명': 'KGM', '판매량': '4043', '점유율': '3.5', '전월 판매량': '5758', '전월 대비 증감': '-1715', '판매월': '2023-07'}
# {'회사명': '르노코리아', '판매량': '1705', '점유율': '1.5', '전월 판매량': '1721', '전월 대비 증감': '-16', '판매월': '2023-07'}
# 2023-08
# {'회사명': '현대', '판매량': '46375', '점유율': '43.5', '전월 판매량': '47048', '전월 대비 증감': '-673', '판매월': '2023-08'}
# {'회사명': '기아', '판매량': '42334', '점유율': '39.7', '전월 판매량': '47507', '전월 대비 증감': '-5173', '판매월': '2023-08'}
# {'회사명': '제네시스', '판매량': '9180', '점유율': '8.6', '전월 판매량': '10455', '전월 대비 증감': '-1275', '판매월': '2023-08'}
# {'회사명': 'KGM', '판매량': '3903', '점유율': '3.7', '전월 판매량': '4043', '전월 대비 증감': '-140', '판매월': '2023-08'}
# {'회사명': '쉐보레', '판매량': '3259', '점유율': '3.1', '전월 판매량': '4086', '전월 대비 증감': '-827', '판매월': '2023-08'}
# {'회사명': '르노코리아', '판매량': '1502', '점유율': '1.4', '전월 판매량': '1705', '전월 대비 증감': '-203', '판매월': '2023-08'}
# 2023-09
# {'회사명': '현대', '판매량': '45397', '점유율': '42.6', '전월 판매량': '46375', '전월 대비 증감': '-978', '판매월': '2023-09'}
# {'회사명': '기아', '판매량': '44410', '점유율': '41.6', '전월 판매량': '42334', '전월 대비 증감': '2076', '판매월': '2023-09'}
# {'회사명': '제네시스', '판매량': '8514', '점유율': '8.0', '전월 판매량': '9180', '전월 대비 증감': '-666', '판매월': '2023-09'}
# {'회사명': 'KGM', '판매량': '4069', '점유율': '3.8', '전월 판매량': '3903', '전월 대비 증감': '166', '판매월': '2023-09'}
# {'회사명': '쉐보레', '판매량': '2602', '점유율': '2.4', '전월 판매량': '3259', '전월 대비 증감': '-657', '판매월': '2023-09'}
# {'회사명': '르노코리아', '판매량': '1651', '점유율': '1.5', '전월 판매량': '1502', '전월 대비 증감': '149', '판매월': '2023-09'}
# 2023-10
# {'회사명': '현대', '판매량': '56732', '점유율': '48.4', '전월 판매량': '45397', '전월 대비 증감': '11335', '판매월': '2023-10'}
# {'회사명': '기아', '판매량': '43254', '점유율': '36.9', '전월 판매량': '44410', '전월 대비 증감': '-1156', '판매월': '2023-10'}
# {'회사명': '제네시스', '판매량': '7596', '점유율': '6.5', '전월 판매량': '8514', '전월 대비 증감': '-918', '판매월': '2023-10'}
# {'회사명': '쉐보레', '판매량': '4437', '점유율': '3.8', '전월 판매량': '2602', '전월 대비 증감': '1835', '판매월': '2023-10'}
# {'회사명': 'KGM', '판매량': '3804', '점유율': '3.2', '전월 판매량': '4069', '전월 대비 증감': '-265', '판매월': '2023-10'}
# {'회사명': '르노코리아', '판매량': '1451', '점유율': '1.2', '전월 판매량': '1651', '전월 대비 증감': '-200', '판매월': '2023-10'}
# 2023-11
# {'회사명': '현대', '판매량': '61169', '점유율': '46.2', '전월 판매량': '56732', '전월 대비 증감': '4437', '판매월': '2023-11'}
# {'회사명': '기아', '판매량': '50322', '점유율': '38.0', '전월 판매량': '43254', '전월 대비 증감': '7068', '판매월': '2023-11'}
# {'회사명': '제네시스', '판매량': '10889', '점유율': '8.2', '전월 판매량': '7596', '전월 대비 증감': '3293', '판매월': '2023-11'}
# {'회사명': 'KGM', '판매량': '5050', '점유율': '3.8', '전월 판매량': '3804', '전월 대비 증감': '1246', '판매월': '2023-11'}
# {'회사명': '쉐보레', '판매량': '2994', '점유율': '2.3', '전월 판매량': '4437', '전월 대비 증감': '-1443', '판매월': '2023-11'}
# {'회사명': '르노코리아', '판매량': '1875', '점유율': '1.4', '전월 판매량': '1451', '전월 대비 증감': '424', '판매월': '2023-11'}
# 2023-12
# {'회사명': '현대', '판매량': '51474', '점유율': '44.9', '전월 판매량': '61169', '전월 대비 증감': '-9695', '판매월': '2023-12'}
# {'회사명': '기아', '판매량': '45167', '점유율': '39.4', '전월 판매량': '50322', '전월 대비 증감': '-5155', '판매월': '2023-12'}
# {'회사명': '제네시스', '판매량': '10694', '점유율': '9.3', '전월 판매량': '10889', '전월 대비 증감': '-195', '판매월': '2023-12'}
# {'회사명': 'KGM', '판매량': '3507', '점유율': '3.1', '전월 판매량': '5050', '전월 대비 증감': '-1543', '판매월': '2023-12'}
# {'회사명': '쉐보레', '판매량': '2194', '점유율': '1.9', '전월 판매량': '2994', '전월 대비 증감': '-800', '판매월': '2023-12'}
# {'회사명': '르노코리아', '판매량': '1594', '점유율': '1.4', '전월 판매량': '1875', '전월 대비 증감': '-281', '판매월': '2023-12'}
# 2024-01
# {'회사명': '기아', '판매량': '44683', '점유율': '43.3', '전월 판매량': '45167', '전월 대비 증감': '-484', '판매월': '2024-01'}
# {'회사명': '현대', '판매량': '38771', '점유율': '37.6', '전월 판매량': '51474', '전월 대비 증감': '-12703', '판매월': '2024-01'}
# {'회사명': '제네시스', '판매량': '11349', '점유율': '11.0', '전월 판매량': '10694', '전월 대비 증감': '655', '판매월': '2024-01'}
# {'회사명': 'KGM', '판매량': '3762', '점유율': '3.6', '전월 판매량': '3507', '전월 대비 증감': '255', '판매월': '2024-01'}
# {'회사명': '쉐보레', '판매량': '2880', '점유율': '2.8', '전월 판매량': '2194', '전월 대비 증감': '686', '판매월': '2024-01'}
# {'회사명': '르노코리아', '판매량': '1645', '점유율': '1.6', '전월 판매량': '1594', '전월 대비 증감': '51', '판매월': '2024-01'}
# 2024-02
# {'회사명': '기아', '판매량': '44068', '점유율': '44.4', '전월 판매량': '44683', '전월 대비 증감': '-615', '판매월': '2024-02'}
# {'회사명': '현대', '판매량': '37071', '점유율': '37.4', '전월 판매량': '38771', '전월 대비 증감': '-1700', '판매월': '2024-02'}
# {'회사명': '제네시스', '판매량': '10582', '점유율': '10.7', '전월 판매량': '11349', '전월 대비 증감': '-767', '판매월': '2024-02'}
# {'회사명': 'KGM', '판매량': '3748', '점유율': '3.8', '전월 판매량': '3762', '전월 대비 증감': '-14', '판매월': '2024-02'}
# {'회사명': '쉐보레', '판매량': '1963', '점유율': '2.0', '전월 판매량': '2880', '전월 대비 증감': '-917', '판매월': '2024-02'}
# {'회사명': '르노코리아', '판매량': '1807', '점유율': '1.8', '전월 판매량': '1645', '전월 대비 증감': '162', '판매월': '2024-02'}
# 2024-03
# {'회사명': '현대', '판매량': '50665', '점유율': '42.2', '전월 판매량': '37071', '전월 대비 증감': '13594', '판매월': '2024-03'}
# {'회사명': '기아', '판매량': '49112', '점유율': '40.9', '전월 판매량': '44068', '전월 대비 증감': '5044', '판매월': '2024-03'}
# {'회사명': '제네시스', '판매량': '11674', '점유율': '9.7', '전월 판매량': '10582', '전월 대비 증감': '1092', '판매월': '2024-03'}
# {'회사명': 'KGM', '판매량': '4702', '점유율': '3.9', '전월 판매량': '3748', '전월 대비 증감': '954', '판매월': '2024-03'}
# {'회사명': '르노코리아', '판매량': '2039', '점유율': '1.7', '전월 판매량': '1807', '전월 대비 증감': '232', '판매월': '2024-03'}
# {'회사명': '쉐보레', '판매량': '2003', '점유율': '1.7', '전월 판매량': '1963', '전월 대비 증감': '40', '판매월': '2024-03'}
# 2024-04
# {'회사명': '현대', '판매량': '51949', '점유율': '43.6', '전월 판매량': '50665', '전월 대비 증감': '1284', '판매월': '2024-04'}
# {'회사명': '기아', '판매량': '47631', '점유율': '40.0', '전월 판매량': '49112', '전월 대비 증감': '-1481', '판매월': '2024-04'}
# {'회사명': '제네시스', '판매량': '11784', '점유율': '9.9', '전월 판매량': '11674', '전월 대비 증감': '110', '판매월': '2024-04'}
# {'회사명': 'KGM', '판매량': '3663', '점유율': '3.1', '전월 판매량': '4702', '전월 대비 증감': '-1039', '판매월': '2024-04'}
# {'회사명': '쉐보레', '판매량': '2266', '점유율': '1.9', '전월 판매량': '2003', '전월 대비 증감': '263', '판매월': '2024-04'}
# {'회사명': '르노코리아', '판매량': '1780', '점유율': '1.5', '전월 판매량': '2039', '전월 대비 증감': '-259', '판매월': '2024-04'}
# 2024-05
# {'회사명': '현대', '판매량': '52064', '점유율': '44.7', '전월 판매량': '51949', '전월 대비 증감': '115', '판매월': '2024-05'}
# {'회사명': '기아', '판매량': '46111', '점유율': '39.6', '전월 판매량': '47631', '전월 대비 증감': '-1520', '판매월': '2024-05'}
# {'회사명': '제네시스', '판매량': '10136', '점유율': '8.7', '전월 판매량': '11784', '전월 대비 증감': '-1648', '판매월': '2024-05'}
# {'회사명': 'KGM', '판매량': '4001', '점유율': '3.4', '전월 판매량': '3663', '전월 대비 증감': '338', '판매월': '2024-05'}
# {'회사명': '쉐보레', '판매량': '2317', '점유율': '2.0', '전월 판매량': '2266', '전월 대비 증감': '51', '판매월': '2024-05'}
# {'회사명': '르노코리아', '판매량': '1901', '점유율': '1.6', '전월 판매량': '1780', '전월 대비 증감': '121', '판매월': '2024-05'}
# 2024-06
# {'회사명': '현대', '판매량': '47699', '점유율': '42.6', '전월 판매량': '52064', '전월 대비 증감': '-4365', '판매월': '2024-06'}
# {'회사명': '기아', '판매량': '44284', '점유율': '39.5', '전월 판매량': '46111', '전월 대비 증감': '-1827', '판매월': '2024-06'}
# {'회사명': '제네시스', '판매량': '12104', '점유율': '10.8', '전월 판매량': '10136', '전월 대비 증감': '1968', '판매월': '2024-06'}
# {'회사명': 'KGM', '판매량': '4102', '점유율': '3.7', '전월 판매량': '4001', '전월 대비 증감': '101', '판매월': '2024-06'}
# {'회사명': '르노코리아', '판매량': '2041', '점유율': '1.8', '전월 판매량': '1901', '전월 대비 증감': '140', '판매월': '2024-06'}
# {'회사명': '쉐보레', '판매량': '1871', '점유율': '1.7', '전월 판매량': '2317', '전월 대비 증감': '-446', '판매월': '2024-06'}
# 2024-07
# {'회사명': '기아', '판매량': '46238', '점유율': '42.0', '전월 판매량': '44284', '전월 대비 증감': '1954', '판매월': '2024-07'}
# {'회사명': '현대', '판매량': '45306', '점유율': '41.1', '전월 판매량': '47699', '전월 대비 증감': '-2393', '판매월': '2024-07'}
# {'회사명': '제네시스', '판매량': '10703', '점유율': '9.7', '전월 판매량': '12104', '전월 대비 증감': '-1401', '판매월': '2024-07'}
# {'회사명': 'KGM', '판매량': '4237', '점유율': '3.8', '전월 판매량': '4102', '전월 대비 증감': '135', '판매월': '2024-07'}
# {'회사명': '쉐보레', '판매량': '2164', '점유율': '2.0', '전월 판매량': '1871', '전월 대비 증감': '293', '판매월': '2024-07'}
# {'회사명': '르노코리아', '판매량': '1469', '점유율': '1.3', '전월 판매량': '2041', '전월 대비 증감': '-572', '판매월': '2024-07'}
# 2024-08
# {'회사명': '현대', '판매량': '47764', '점유율': '45.2', '전월 판매량': '45306', '전월 대비 증감': '2458', '판매월': '2024-08'}
# {'회사명': '기아', '판매량': '40685', '점유율': '38.5', '전월 판매량': '46238', '전월 대비 증감': '-5553', '판매월': '2024-08'}
# {'회사명': '제네시스', '판매량': '10323', '점유율': '9.8', '전월 판매량': '10703', '전월 대비 증감': '-380', '판매월': '2024-08'}
# {'회사명': 'KGM', '판매량': '3943', '점유율': '3.7', '전월 판매량': '4237', '전월 대비 증감': '-294', '판매월': '2024-08'}
# {'회사명': '쉐보레', '판매량': '1587', '점유율': '1.5', '전월 판매량': '2164', '전월 대비 증감': '-577', '판매월': '2024-08'}
# {'회사명': '르노코리아', '판매량': '1350', '점유율': '1.3', '전월 판매량': '1469', '전월 대비 증감': '-119', '판매월': '2024-08'}

# %%
df = pd.DataFrame(data_list)
df
# Out:
#        회사명    판매량   점유율 전월 판매량 전월 대비 증감      판매월
# 0       기아  37038  39.4  47789   -10751  2022-01
# 1       현대  35625  37.9  51240   -15615  2022-01
# 2     제네시스  10575  11.3  14872    -4297  2022-01
# 3      KGM   4836   5.2   5810     -974  2022-01
# 4    르노코리아   4477   4.8   7162    -2685  2022-01
# ..     ...    ...   ...    ...      ...      ...
# 187     기아  40685  38.5  46238    -5553  2024-08
# 188   제네시스  10323   9.8  10703     -380  2024-08
# 189    KGM   3943   3.7   4237     -294  2024-08
# 190    쉐보레   1587   1.5   2164     -577  2024-08
# 191  르노코리아   1350   1.3   1469     -119  2024-08
#
# [192 rows x 6 columns]

# %%
import mysql.connector

# 데이터베이스 연결 설정
db_config = {
    'host': 'localhost',
    'user': 'root',
    'password': '1234',
    'database': 'pjt01'
}


# 데이터베이스 연결
try:
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor(buffered=True)

    for entry in data_list:
        company_name = entry['회사명']
        
        # 모델명을 통해 vehicle_id 가져오기
        cursor.execute("SELECT company_id FROM company WHERE company_name = %s", (company_name,))
        company_id = cursor.fetchone()
        
        if company_id:
            company_id = company_id[0]  # 첫 번째 요소 가져오기
            
            # 데이터 삽입
            cursor.execute("""
                INSERT INTO domestic_company_sales (sales, market_share, last_month_sales, last_month_change, sales_month, company_id) 
                VALUES (%s, %s, %s, %s, %s, %s)
            """, (entry['판매량'], entry['점유율'], entry['전월 판매량'], entry['전월 대비 증감'], entry['판매월']+'-01', company_id))
        else:
            print(f"{company_name}에 대한 company_id를 찾을 수 없습니다.")

    # 변경 사항 커밋
    conn.commit()
    print("데이터가 성공적으로 삽입되었습니다.")

except mysql.connector.Error as err:
    print(f"오류 발생: {err}")

finally:
    if cursor:
        cursor.close()
    if conn:
        conn.close()
# Out:
# 데이터가 성공적으로 삽입되었습니다.
